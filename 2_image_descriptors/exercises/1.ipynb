# %% [markdown]
# Modify the function for matching Harris corner points to also take a maximum pixel distance between points for them to be considered as correspondences in order to make matching more robust.

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from mod_harris import *

# %%
im1 = np.array(Image.open('../../data/crans_1_small.jpg').convert('L'))
im2 = np.array(Image.open('../../data/crans_2_small.jpg').convert('L'))

# %%
wid = 5
harrisim = compute_harris_response(im1, 5)
filtered_coords1 = get_harris_points(harrisim, wid + 1)
d1 = get_descriptors(im, filtered_coords1, wid)

harrisim = compute_harris_response(im2, 5)
filtered_coords2 = get_harris_points(harrisim, wid + 1)
d2 = get_descriptors(im, filtered_coords2, wid)

print("Starting matching")
matches = match_twosided(d1, d2)

plt.figure()
plt.gray()
plot_matches(im1, im2, filtered_coords1, filtered_coords2, matches)
plt.show()
# Out:
# Starting matching
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 11
#       8 d2 = get_descriptors(im, filtered_coords2, wid)
#      10 print("Starting matching")
# ---> 11 matches = match_twosided(d1, d2)
#      13 plt.figure()
#      14 plt.gray()
#
# File c:\Users\joel\Documents\Projects\computer-vision\2_image_descriptors\exercises\mod_harris.py:112, in match_twosided(desc1, desc2, threshold)
#     110 def match_twosided(desc1, desc2, threshold=0.5):
#     111     """ Two-sided symmetric version of match(). """
# --> 112     matches_12 = match(desc1, desc2, threshold)
#     113     matches_21 = match(desc2, desc1, threshold)
#     115     ndx_12 = np.where(matches_12 >= 0)[0]
#
# File c:\Users\joel\Documents\Projects\computer-vision\2_image_descriptors\exercises\mod_harris.py:100, in match(desc1, desc2, threshold)
#      98 d1 = (desc1[i] - np.mean(desc1[i])) / np.std(desc1[i])
#      99 d2 = (desc2[j] - np.mean(desc2[j])) / np.std(desc2[j])
# --> 100 ncc_value = np.sum(d1 * d2) / (n - 1)
#     101 if ncc_value > threshold:
#     102     d[i, j] = ncc_value
#
# ValueError: operands could not be broadcast together with shapes (121,) (0,)
