# %% [markdown]
# An alternative corner detector to Harris is the FAST corner detector. There are a number of implementations inlcuding a pure Python version available at http://www.edwardrosten.com/work/fast.html. Try this detector, play with the sensitivity threshold, and compare the corners with the ones from our Harris implementation.

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import fast

# %%
fast.get_bresenham_circle(1, 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 fast.get_bresenham_circle(1, 1)
#
# File ~/computer-vision/2_image_descriptors/exercises/fast.py:17, in get_bresenham_circle(circle_x, circle_y)
#      14 actual_y = circle_y
#      16 circle_points = np.array([16, 2])
# ---> 17 circle_points[0][0] = actual_x
#      18 circle_points[0][1] = actual_y
#      20 return circle_points
#
# TypeError: 'numpy.int64' object does not support item assignment
