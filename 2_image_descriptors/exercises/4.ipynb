# %% [markdown]
# Create copies of an image with different resolutions (for example by halving the size a few times). Extract SIFT features of each image. Plot and match features to fet a feel for how and when the scale independence breaks down.
