# %%
# !pip install
# Out:
# ERROR: Could not find a version that satisfies the requirement wheels (from versions: none)
# ERROR: No matching distribution found for wheels

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import sift

# %%
imname = '../data/empire.jpg'
im1 = np.array(Image.open(imname).convert('L'))

plt.figure()
plt.gray()
plt.imshow(im1)

# %%
sift.process_image(imname, 'empire.sift')
l1, d1 = sift.read_features_from_file('empire.sift')
"""
plt.figure()
plt.gray()
sift.plot_features(im1, l1, circle=True)
plt.show()
"""
# Out:
# Processed tmp.pgm to empire.sift
# c:\Users\joel0\Documents\Active Projects\ComputerVision\2_image_descriptors\sift.py:25: UserWarning: loadtxt: input contained no data: "empire.sift"
#   f = np.loadtxt(filename)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 sift.process_image(imname, 'empire.sift')
# ----> 2 l1, d1 = sift.read_features_from_file('empire.sift')
#       3 """
#       4 plt.figure()
#       5 plt.gray()
#       6 sift.plot_features(im1, l1, circle=True)
#       7 plt.show()
#       8 """
#
# File c:\Users\joel0\Documents\Active Projects\ComputerVision\2_image_descriptors\sift.py:26, in read_features_from_file(filename)
#      23 """ Read feature properties and return in matrix form. """
#      25 f = np.loadtxt(filename)
# ---> 26 return f[:,:4],f[:,4:]
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
