# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Plotting images, points and lines

# %%
# read image to array
im = np.array(Image.open('Resources/bird.jpg'))

# plot the image
plt.imshow(im)

# some points
x = [100, 100, 400, 400]
y = [200, 500, 200, 500]

# plot the points with red star-markers
#plot(x, y, 'r*')

# line plot connecting the first two points
#plot(x[:2], y[:2])

# remove axis
plt.axis('off')

# add tittle and show the plot
plt.title('Plotting: "Resources/bird.jpg"')
plt.show()

# %% [markdown]
# # Image contours and histograms

# %% [markdown]
# ## Contour plot

# %%
# read image to array and convert to grayscale
im = np.array(Image.open('Resources/bird.jpg').convert('L'))

# create a new figure
plt.figure()
# don't use colors
plt.gray()
# show contours with origin upper left corner
plt.contour(im, origin='image')
plt.axis('equal')
plt.axis('off')
# Out:
# (0.5, 1919.5, 0.5, 1199.5)

# %% [markdown]
# ## Histogram plot

# %%
plt.figure()
plt.hist(im.flatten(), 128)
plt.show()

# %% [markdown]
# # Interactive annotation

# %%
im = np.array(Image.open('Resources/bird.jpg'))
plt.imshow(im)
print('Please click 3 points')
x = plt.ginput(3)
print('You clicked: ', x)
plt.show()
# Out:
# Please click 3 points
# C:\Users\joel0\AppData\Local\Temp\ipykernel_8972\4129315809.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   x = ginput(3)
# You clicked:  []
